# %% [markdown]
# <a href="https://colab.research.google.com/github/New-TW/TFT_IV_Parameters/blob/main/ITZO_TFT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
as_depo = '/content/drive/My Drive/Labwork/as depo.txt'
x=np.loadtxt(as_depo)
gateV=x[:,0]
drainI=(x[:,1])
plt.title("as Depo",fontsize=25)
plt.xlabel("Gate V")
plt.ylabel("Drain I")
plt.plot(gateV,np.log(drainI))
plt.show()

# %%
as_depo = '/content/drive/My Drive/Labwork/as depo.txt'
x=np.loadtxt(as_depo)
gateV=x[:,0]
drainI=(x[:,1])
plt.title("as Depo",fontsize=25)
plt.xlabel("Gate V")
plt.ylabel("Drain I")
plt.plot(gateV,drainI)
plt.show()

# %%
as_depo_20 = '/content/drive/My Drive/Labwork/as depo_20.txt'
x=np.loadtxt(as_depo_20)
gateV=x[:,0]
drainI=(x[:,1])
plt.title("as Depo in 20V",fontsize=25)
plt.xlabel("Gate V")
plt.ylabel("Drain I")
plt.plot(gateV,np.log(drainI))
plt.show()

# %%
as_depo_20 = '/content/drive/My Drive/Labwork/as depo_20.txt'
x=np.loadtxt(as_depo_20)
gateV=x[:,0]
drainI=(x[:,1])
plt.title("as Depo in 20V",fontsize=25)
plt.xlabel("Gate V")
plt.ylabel("Drain I")
plt.plot(gateV,np.log(drainI))
plt.show()

# %%
c_200 = '/content/drive/My Drive/Labwork/200.txt'
x=np.loadtxt(c_200)
gateV=x[:,0]
drainI=(x[:,1])
plt.title("200°C",fontsize=25)
plt.xlabel("Gate V")
plt.ylabel("Drain I")
plt.plot(gateV,np.log(drainI))
plt.show()

# %%
c_200_20_2 = '/content/drive/My Drive/Labwork/200_20(2).txt'
x=np.loadtxt(c_200_20_2)
gateV=x[:,0]
drainI=(x[:,1])
plt.title("200°C in 20V",fontsize=25)
plt.xlabel("Gate V")
plt.ylabel("Drain I")
plt.plot(gateV,np.log(drainI))
plt.show()

# %%
c_250 = '/content/drive/My Drive/Labwork/250.txt'
x=np.loadtxt(c_250)
gateV=x[:,0]
drainI=(x[:,1])
plt.title("250°C",fontsize=25)
plt.xlabel("Gate V")
plt.ylabel("Drain I")
plt.plot(gateV,np.log(drainI))
plt.show()

# %%
c_250_20 = '/content/drive/My Drive/Labwork/250_20.txt'
x=np.loadtxt(c_250_20)
gateV=x[:,0]
drainI=(x[:,1])
plt.title("250°C in 20V",fontsize=25)
plt.xlabel("Gate V")
plt.ylabel("Drain I")
plt.plot(gateV,np.log(drainI))
plt.show()

# %%
c_300 = '/content/drive/My Drive/Labwork/300.txt'
x=np.loadtxt(c_300)
gateV=x[:,0]
drainI=(x[:,1])
plt.title("300°C",fontsize=25)
plt.xlabel("Gate V")
plt.ylabel("Drain I")
plt.plot(gateV,np.log(drainI))
plt.show()

# %%
c_300_20 = '/content/drive/My Drive/Labwork/300_20.txt'
x=np.loadtxt(c_300_20)
gateV=x[:,0]
drainI=(x[:,1])
plt.title("300°C in 20V",fontsize=25)
plt.xlabel("Gate V")
plt.ylabel("Drain I")
plt.plot(gateV,np.log(drainI))
plt.show()
